# %% [markdown]
# # Продажи австралийского вина
# Известны ежемесячные продажи австралийского вина в тысячах литров с января 1980 по июль 1995, необходимо построить прогноз на следующие два года.

# %%
import numpy as np
import pandas as pd
import scipy.stats as st
import matplotlib.pylab as plt
import seaborn as sns

from statsmodels.tsa.stattools import kpss
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX

from statsmodels.stats.diagnostic import acorr_ljungbox

from statsmodels.tsa.holtwinters import ExponentialSmoothing

plt.rcParams['figure.figsize'] = (12,8)

# %%
data = pd.read_csv('monthly-australian-wine-sales-th.csv', parse_dates=[0], delimiter=',')
data.head()
# Out:
#        Month  \
# 0 1980-01-01
# 1 1980-02-01
# 2 1980-03-01
# 3 1980-04-01
# 4 1980-05-01
#
#    Monthly Australian wine sales: thousands of litres. By wine makers in bottles <= 1 litre.
# 0                                              15136
# 1                                              16733
# 2                                              20016
# 3                                              17708
# 4                                              18019

# %%
data.columns = ['date', 'wine']
data.head(5)
# Out:
#         date   wine
# 0 1980-01-01  15136
# 1 1980-02-01  16733
# 2 1980-03-01  20016
# 3 1980-04-01  17708
# 4 1980-05-01  18019

# %%
sns.lineplot(data['date'],data['wine'])

plt.show()
# Out:
# /Users/vitalijugnivenko/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Попробуем поделить на число дней в месяце:

# %%
values = data['wine'].values.copy()
days = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
for i in range(len(values)):
    values[i]/=days[i%12]
sns.lineplot(data['date'],values)

plt.show()

# %% [markdown]
# Ряд не стал более регулярным, так что вернёмся к исходным данным.
#
# STL-декомпозиция ряда:

# %%
data = data.set_index(pd.DatetimeIndex(data['date']))

# %%
data.head()
# Out:
#                  date   wine
# date
# 1980-01-01 1980-01-01  15136
# 1980-02-01 1980-02-01  16733
# 1980-03-01 1980-03-01  20016
# 1980-04-01 1980-04-01  17708
# 1980-05-01 1980-05-01  18019

# %%
plt.rcParams['figure.figsize'] = (9.0, 6.0)
plt.style.use('seaborn-whitegrid')
plt.rcParams.update({'font.size': 14})
stl_data = seasonal_decompose(data['wine'])
_= stl_data.plot()

# %%
transformed, lam = st.boxcox(data['wine'])
data['bc'] = transformed
print (lam)
stl_data = seasonal_decompose(transformed, period=12)
_= stl_data.plot()
# Out:
# 0.23667537162383442

# %% [markdown]
# # ARIMA
# Стационарность:

# %%
kpss(data['wine'], nlags='legacy')
# Out:
# (0.5448466202836393,
#  0.03156607651269385,
#  14,
#  {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739})

# %% [markdown]
# Cделаем сезонное дифференцирование:

# %%
diff_ts = data['wine'].diff(12)[12:]
plt.plot(diff_ts)
kpss(diff_ts, nlags='legacy')
# Out:
# (0.5200996002022095,
#  0.03713972968418706,
#  14,
#  {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739})

# %% [markdown]
# Ряд всё ещё нестационарен. Проведём ещё одно дифференцирование:

# %%
diff_diff_ts = diff_ts.diff(1)[1:]
plt.plot(diff_diff_ts)
kpss(diff_diff_ts, nlags='legacy')
# Out:
# /Users/vitalijugnivenko/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/stattools.py:1687: InterpolationWarning: p-value is greater than the indicated p-value
#   warn("p-value is greater than the indicated p-value", InterpolationWarning)
# (0.1466436817476703,
#  0.1,
#  14,
#  {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739})

# %% [markdown]
# Для полученного ряда гипотеза стационарности не отвергается

# %% [markdown]
# Посмотрим на ACF и PACF полученного продифференцированного ряда:

# %%
plot_acf(diff_diff_ts, lags=15)

plt.show()

# %%
plot_pacf(diff_diff_ts, lags=15)

plt.show()

# %% [markdown]
# На ACF значимы лаги 1 и 12, на PACF — 1-3. Будем искать модель, оптимальную по AICc, в окрестности ARIMA(3,1,1)

# %%
for i in range(-1,2):
    for k in range(-1, 2):
        order = (3+i,1,1+k)
        try:
            arima = ARIMA(data['wine'].values, order=order).fit()
            print(arima.summary())
        except:
            pass
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                    D.y   No. Observations:                  175
# Model:                 ARIMA(2, 1, 0)   Log Likelihood               -1764.553
# Method:                       css-mle   S.D. of innovations           5783.214
# Date:                Tue, 28 Apr 2020   AIC                           3537.107
# Time:                        09:50:49   BIC                           3549.766
# Sample:                             1   HQIC                          3542.242
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         52.9051    234.100      0.226      0.821    -405.923     511.733
# ar.L1.D.y     -0.4337      0.068     -6.399      0.000      -0.566      -0.301
# ar.L2.D.y     -0.4413      0.067     -6.550      0.000      -0.573      -0.309
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.4913           -1.4228j            1.5053           -0.3029
# AR.2           -0.4913           +1.4228j            1.5053            0.3029
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                    D.y   No. Observations:                  175
# Model:                 ARIMA(2, 1, 1)   Log Likelihood               -1739.339
# Method:                       css-mle   S.D. of innovations           4980.096
# Date:                Tue, 28 Apr 2020   AIC                           3488.678
# Time:                        09:50:49   BIC                           3504.502
# Sample:                             1   HQIC                          3495.097
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         31.1274     24.556      1.268      0.205     -17.001      79.255
# ar.L1.D.y      0.1196      0.075      1.596      0.110      -0.027       0.267
# ar.L2.D.y     -0.2752      0.074     -3.700      0.000      -0.421      -0.129
# ma.L1.D.y     -0.9314      0.026    -36.182      0.000      -0.982      -0.881
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            0.2174           -1.8938j            1.9062           -0.2318
# AR.2            0.2174           +1.8938j            1.9062            0.2318
# MA.1            1.0736           +0.0000j            1.0736            0.0000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                    D.y   No. Observations:                  175
# Model:                 ARIMA(2, 1, 2)   Log Likelihood               -1739.338
# Method:                       css-mle   S.D. of innovations           4980.096
# Date:                Tue, 28 Apr 2020   AIC                           3490.677
# Time:                        09:50:49   BIC                           3509.665
# Sample:                             1   HQIC                          3498.379
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         31.1114     24.553      1.267      0.205     -17.012      79.235
# ar.L1.D.y      0.1130      0.202      0.560      0.576      -0.283       0.509
# ar.L2.D.y     -0.2744      0.078     -3.535      0.000      -0.427      -0.122
# ma.L1.D.y     -0.9243      0.204     -4.539      0.000      -1.323      -0.525
# ma.L2.D.y     -0.0068      0.193     -0.035      0.972      -0.385       0.372
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            0.2059           -1.8977j            1.9089           -0.2328
# AR.2            0.2059           +1.8977j            1.9089            0.2328
# MA.1            1.0734           +0.0000j            1.0734            0.0000
# MA.2         -136.0243           +0.0000j          136.0243            0.5000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                    D.y   No. Observations:                  175
# Model:                 ARIMA(3, 1, 0)   Log Likelihood               -1750.849
# Method:                       css-mle   S.D. of innovations           5340.469
# Date:                Tue, 28 Apr 2020   AIC                           3511.697
# Time:                        09:50:49   BIC                           3527.521
# Sample:                             1   HQIC                          3518.116
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         51.2146    156.987      0.326      0.744    -256.475     358.904
# ar.L1.D.y     -0.6029      0.070     -8.635      0.000      -0.740      -0.466
# ar.L2.D.y     -0.6069      0.069     -8.781      0.000      -0.742      -0.471
# ar.L3.D.y     -0.3788      0.069     -5.466      0.000      -0.515      -0.243
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            0.0106           -1.2752j            1.2752           -0.2487
# AR.2            0.0106           +1.2752j            1.2752            0.2487
# AR.3           -1.6235           -0.0000j            1.6235           -0.5000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                    D.y   No. Observations:                  175
# Model:                 ARIMA(3, 1, 1)   Log Likelihood               -1739.338
# Method:                       css-mle   S.D. of innovations           4980.097
# Date:                Tue, 28 Apr 2020   AIC                           3490.676
# Time:                        09:50:49   BIC                           3509.664
# Sample:                             1   HQIC                          3498.378
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         31.0950     24.553      1.266      0.205     -17.027      79.217
# ar.L1.D.y      0.1210      0.080      1.515      0.130      -0.036       0.278
# ar.L2.D.y     -0.2754      0.075     -3.696      0.000      -0.421      -0.129
# ar.L3.D.y      0.0038      0.079      0.049      0.961      -0.151       0.158
# ma.L1.D.y     -0.9318      0.027    -34.908      0.000      -0.984      -0.879
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            0.1952           -1.9007j            1.9107           -0.2337
# AR.2            0.1952           +1.9007j            1.9107            0.2337
# AR.3           71.2152           -0.0000j           71.2152           -0.0000
# MA.1            1.0732           +0.0000j            1.0732            0.0000
# -----------------------------------------------------------------------------
# /Users/vitalijugnivenko/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/tsatools.py:672: RuntimeWarning: invalid value encountered in arctanh
#   invarcoefs = 2*np.arctanh(params)
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                    D.y   No. Observations:                  175
# Model:                 ARIMA(4, 1, 0)   Log Likelihood               -1749.878
# Method:                       css-mle   S.D. of innovations           5310.240
# Date:                Tue, 28 Apr 2020   AIC                           3511.757
# Time:                        09:50:49   BIC                           3530.745
# Sample:                             1   HQIC                          3519.459
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         50.8815    141.359      0.360      0.719    -226.177     327.940
# ar.L1.D.y     -0.6435      0.075     -8.547      0.000      -0.791      -0.496
# ar.L2.D.y     -0.6711      0.083     -8.114      0.000      -0.833      -0.509
# ar.L3.D.y     -0.4422      0.082     -5.361      0.000      -0.604      -0.281
# ar.L4.D.y     -0.1043      0.075     -1.397      0.162      -0.251       0.042
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            0.1102           -1.2866j            1.2913           -0.2364
# AR.2            0.1102           +1.2866j            1.2913            0.2364
# AR.3           -2.2302           -0.8812j            2.3980           -0.4401
# AR.4           -2.2302           +0.8812j            2.3980            0.4401
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                    D.y   No. Observations:                  175
# Model:                 ARIMA(4, 1, 1)   Log Likelihood               -1738.141
# Method:                       css-mle   S.D. of innovations           4946.794
# Date:                Tue, 28 Apr 2020   AIC                           3490.281
# Time:                        09:50:50   BIC                           3512.435
# Sample:                             1   HQIC                          3499.267
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         30.5782     24.709      1.238      0.216     -17.851      79.007
# ar.L1.D.y      0.1320      0.080      1.644      0.100      -0.025       0.289
# ar.L2.D.y     -0.2352      0.079     -2.980      0.003      -0.390      -0.081
# ar.L3.D.y     -0.0006      0.079     -0.007      0.994      -0.155       0.154
# ar.L4.D.y      0.1211      0.078      1.543      0.123      -0.033       0.275
# ma.L1.D.y     -0.9420      0.027    -34.726      0.000      -0.995      -0.889
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            0.0908           -1.4370j            1.4399           -0.2400
# AR.2            0.0908           +1.4370j            1.4399            0.2400
# AR.3            1.9095           -0.0000j            1.9095           -0.0000
# AR.4           -2.0864           -0.0000j            2.0864           -0.5000
# MA.1            1.0615           +0.0000j            1.0615            0.0000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                    D.y   No. Observations:                  175
# Model:                 ARIMA(4, 1, 2)   Log Likelihood               -1738.006
# Method:                       css-mle   S.D. of innovations           4942.842
# Date:                Tue, 28 Apr 2020   AIC                           3492.013
# Time:                        09:50:50   BIC                           3517.331
# Sample:                             1   HQIC                          3502.283
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         30.5759     24.669      1.239      0.215     -17.775      78.927
# ar.L1.D.y      0.0106      0.245      0.043      0.966      -0.469       0.490
# ar.L2.D.y     -0.2185      0.083     -2.621      0.009      -0.382      -0.055
# ar.L3.D.y     -0.0343      0.101     -0.339      0.734      -0.232       0.164
# ar.L4.D.y      0.1272      0.079      1.620      0.105      -0.027       0.281
# ma.L1.D.y     -0.8188      0.236     -3.465      0.001      -1.282      -0.356
# ma.L2.D.y     -0.1154      0.219     -0.528      0.598      -0.544       0.313
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.8713           -0.0000j            1.8713           -0.5000
# AR.2            0.0545           -1.4367j            1.4377           -0.2440
# AR.3            0.0545           +1.4367j            1.4377            0.2440
# AR.4            2.0318           -0.0000j            2.0318           -0.0000
# MA.1            1.0623           +0.0000j            1.0623            0.0000
# MA.2           -8.1567           +0.0000j            8.1567            0.5000
# -----------------------------------------------------------------------------

# %%
arima = ARIMA(data['wine'].values, order=(2,1,1)).fit()
print(arima.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                    D.y   No. Observations:                  175
# Model:                 ARIMA(2, 1, 1)   Log Likelihood               -1739.339
# Method:                       css-mle   S.D. of innovations           4980.096
# Date:                Tue, 28 Apr 2020   AIC                           3488.678
# Time:                        09:51:12   BIC                           3504.502
# Sample:                             1   HQIC                          3495.097
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         31.1274     24.556      1.268      0.205     -17.001      79.255
# ar.L1.D.y      0.1196      0.075      1.596      0.110      -0.027       0.267
# ar.L2.D.y     -0.2752      0.074     -3.700      0.000      -0.421      -0.129
# ma.L1.D.y     -0.9314      0.026    -36.182      0.000      -0.982      -0.881
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            0.2174           -1.8938j            1.9062           -0.2318
# AR.2            0.2174           +1.8938j            1.9062            0.2318
# MA.1            1.0736           +0.0000j            1.0736            0.0000
# -----------------------------------------------------------------------------

# %%
plt.plot(arima.resid)
plot_pacf(arima.resid, lags=15)
plot_acf(arima.resid, lags=15)

plt.show()

# %%
for i in range(-1,2):
    for j in range(-1, 2):
        order = (3+i, 1, 1+j)
        sorder = (1, 1, 1, 12)
        try:
            arima = SARIMAX(data['wine'].values, order=order, seasonal_order=sorder).fit()
            print(arima.summary())
        except:
            pass
# Out:
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                  176
# Model:             SARIMAX(2, 1, 0)x(1, 1, [1], 12)   Log Likelihood               -1532.390
# Date:                              Tue, 28 Apr 2020   AIC                           3074.781
# Time:                                      09:51:33   BIC                           3090.249
# Sample:                                           0   HQIC                          3081.061
#                                               - 176
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.4661      0.041    -11.448      0.000      -0.546      -0.386
# ar.L2         -0.2971      0.050     -5.915      0.000      -0.396      -0.199
# ar.S.L12       0.1935      0.160      1.208      0.227      -0.121       0.508
# ma.S.L12      -0.5795      0.155     -3.749      0.000      -0.882      -0.277
# sigma2      9.007e+06   9.77e+05      9.216      0.000    7.09e+06    1.09e+07
# ===================================================================================
# Ljung-Box (Q):                       59.71   Jarque-Bera (JB):                 8.97
# Prob(Q):                              0.02   Prob(JB):                         0.01
# Heteroskedasticity (H):               1.38   Skew:                            -0.42
# Prob(H) (two-sided):                  0.23   Kurtosis:                         3.78
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  176
# Model:             SARIMAX(2, 1, 1)x(1, 1, 1, 12)   Log Likelihood               -1527.930
# Date:                            Tue, 28 Apr 2020   AIC                           3067.860
# Time:                                    09:51:34   BIC                           3086.423
# Sample:                                         0   HQIC                          3075.396
#                                             - 176
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0506      0.141      0.358      0.720      -0.226       0.328
# ar.L2         -0.1127      0.081     -1.385      0.166      -0.272       0.047
# ma.L1         -0.6149      0.156     -3.952      0.000      -0.920      -0.310
# ar.S.L12       0.2077      0.164      1.266      0.205      -0.114       0.529
# ma.S.L12      -0.5814      0.157     -3.695      0.000      -0.890      -0.273
# sigma2      8.287e+06   1.86e-08   4.45e+14      0.000    8.29e+06    8.29e+06
# ===================================================================================
# Ljung-Box (Q):                       50.55   Jarque-Bera (JB):                19.05
# Prob(Q):                              0.12   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.15   Skew:                            -0.57
# Prob(H) (two-sided):                  0.62   Kurtosis:                         4.23
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 8.93e+29. Standard errors may be unstable.
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                  176
# Model:             SARIMAX(2, 1, 2)x(1, 1, [1], 12)   Log Likelihood               -1527.632
# Date:                              Tue, 28 Apr 2020   AIC                           3069.263
# Time:                                      09:51:34   BIC                           3090.920
# Sample:                                           0   HQIC                          3078.056
#                                               - 176
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2580      0.674     -0.383      0.702      -1.579       1.063
# ar.L2         -0.0622      0.141     -0.442      0.658      -0.338       0.214
# ma.L1         -0.3129      0.685     -0.457      0.648      -1.655       1.029
# ma.L2         -0.2303      0.496     -0.464      0.643      -1.203       0.742
# ar.S.L12       0.1966      0.158      1.247      0.212      -0.112       0.506
# ma.S.L12      -0.5760      0.157     -3.671      0.000      -0.884      -0.268
# sigma2      7.646e+06   7.43e+05     10.296      0.000    6.19e+06     9.1e+06
# ===================================================================================
# Ljung-Box (Q):                       49.59   Jarque-Bera (JB):                18.86
# Prob(Q):                              0.14   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.15   Skew:                            -0.56
# Prob(H) (two-sided):                  0.62   Kurtosis:                         4.24
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 8.66e+14. Standard errors may be unstable.
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                  176
# Model:             SARIMAX(3, 1, 0)x(1, 1, [1], 12)   Log Likelihood               -1529.639
# Date:                              Tue, 28 Apr 2020   AIC                           3071.278
# Time:                                      09:51:35   BIC                           3089.840
# Sample:                                           0   HQIC                          3078.814
#                                               - 176
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.5193      0.044    -11.880      0.000      -0.605      -0.434
# ar.L2         -0.3764      0.047     -8.019      0.000      -0.468      -0.284
# ar.L3         -0.1549      0.080     -1.935      0.053      -0.312       0.002
# ar.S.L12       0.2368      0.159      1.494      0.135      -0.074       0.547
# ma.S.L12      -0.6078      0.152     -4.004      0.000      -0.905      -0.310
# sigma2      8.236e+06   8.48e+05      9.709      0.000    6.57e+06     9.9e+06
# ===================================================================================
# Ljung-Box (Q):                       56.68   Jarque-Bera (JB):                17.31
# Prob(Q):                              0.04   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.25   Skew:                            -0.57
# Prob(H) (two-sided):                  0.42   Kurtosis:                         4.13
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 8.05e+14. Standard errors may be unstable.
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  176
# Model:             SARIMAX(3, 1, 1)x(1, 1, 1, 12)   Log Likelihood               -1527.899
# Date:                            Tue, 28 Apr 2020   AIC                           3069.798
# Time:                                    09:51:35   BIC                           3091.454
# Sample:                                         0   HQIC                          3078.590
#                                             - 176
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0949      0.253      0.375      0.707      -0.401       0.591
# ar.L2         -0.0903      0.133     -0.677      0.498      -0.352       0.171
# ar.L3          0.0297      0.146      0.204      0.839      -0.256       0.315
# ma.L1         -0.6584      0.255     -2.583      0.010      -1.158      -0.159
# ar.S.L12       0.2025      0.164      1.232      0.218      -0.120       0.525
# ma.S.L12      -0.5780      0.158     -3.656      0.000      -0.888      -0.268
# sigma2      8.287e+06   2.03e-08   4.08e+14      0.000    8.29e+06    8.29e+06
# ===================================================================================
# Ljung-Box (Q):                       50.58   Jarque-Bera (JB):                18.90
# Prob(Q):                              0.12   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.15   Skew:                            -0.56
# Prob(H) (two-sided):                  0.61   Kurtosis:                         4.23
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 6.07e+30. Standard errors may be unstable.
# /Users/vitalijugnivenko/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:963: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /Users/vitalijugnivenko/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                  176
# Model:             SARIMAX(3, 1, 2)x(1, 1, [1], 12)   Log Likelihood               -1527.611
# Date:                              Tue, 28 Apr 2020   AIC                           3071.221
# Time:                                      09:51:36   BIC                           3095.971
# Sample:                                           0   HQIC                          3081.269
#                                               - 176
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.5571      1.984     -0.281      0.779      -4.445       3.331
# ar.L2         -0.0578      0.150     -0.387      0.699      -0.351       0.235
# ar.L3         -0.0418      0.299     -0.140      0.889      -0.627       0.543
# ma.L1         -0.0154      1.986     -0.008      0.994      -3.908       3.878
# ma.L2         -0.4073      1.162     -0.351      0.726      -2.685       1.870
# ar.S.L12       0.1968      0.157      1.253      0.210      -0.111       0.504
# ma.S.L12      -0.5769      0.156     -3.702      0.000      -0.882      -0.271
# sigma2      7.547e+06   7.25e+05     10.409      0.000    6.13e+06    8.97e+06
# ===================================================================================
# Ljung-Box (Q):                       48.83   Jarque-Bera (JB):                19.07
# Prob(Q):                              0.16   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.14   Skew:                            -0.56
# Prob(H) (two-sided):                  0.63   Kurtosis:                         4.24
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 9.61e+14. Standard errors may be unstable.
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                  176
# Model:             SARIMAX(4, 1, 0)x(1, 1, [1], 12)   Log Likelihood               -1528.312
# Date:                              Tue, 28 Apr 2020   AIC                           3070.624
# Time:                                      09:51:37   BIC                           3092.281
# Sample:                                           0   HQIC                          3079.417
#                                               - 176
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.5527      0.044    -12.615      0.000      -0.639      -0.467
# ar.L2         -0.4351      0.052     -8.362      0.000      -0.537      -0.333
# ar.L3         -0.2212      0.095     -2.335      0.020      -0.407      -0.036
# ar.L4         -0.1127      0.068     -1.648      0.099      -0.247       0.021
# ar.S.L12       0.1927      0.157      1.227      0.220      -0.115       0.500
# ma.S.L12      -0.5756      0.156     -3.696      0.000      -0.881      -0.270
# sigma2      7.902e+06   7.95e+05      9.936      0.000    6.34e+06    9.46e+06
# ===================================================================================
# Ljung-Box (Q):                       48.96   Jarque-Bera (JB):                17.74
# Prob(Q):                              0.16   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.20   Skew:                            -0.57
# Prob(H) (two-sided):                  0.50   Kurtosis:                         4.14
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 7.79e+14. Standard errors may be unstable.
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  176
# Model:             SARIMAX(4, 1, 1)x(1, 1, 1, 12)   Log Likelihood               -1527.698
# Date:                            Tue, 28 Apr 2020   AIC                           3071.396
# Time:                                    09:51:37   BIC                           3096.146
# Sample:                                         0   HQIC                          3081.444
#                                             - 176
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0746      0.362      0.206      0.837      -0.636       0.785
# ar.L2         -0.1024      0.205     -0.499      0.618      -0.504       0.300
# ar.L3          0.0211      0.179      0.118      0.906      -0.330       0.373
# ar.L4         -0.0081      0.100     -0.081      0.936      -0.205       0.188
# ma.L1         -0.6422      0.372     -1.725      0.084      -1.372       0.087
# ar.S.L12       0.2006      0.160      1.257      0.209      -0.112       0.513
# ma.S.L12      -0.5777      0.153     -3.769      0.000      -0.878      -0.277
# sigma2      7.924e+06   9.42e-08   8.41e+13      0.000    7.92e+06    7.92e+06
# ===================================================================================
# Ljung-Box (Q):                       50.09   Jarque-Bera (JB):                18.93
# Prob(Q):                              0.13   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.15   Skew:                            -0.56
# Prob(H) (two-sided):                  0.62   Kurtosis:                         4.24
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 5.04e+29. Standard errors may be unstable.
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                  176
# Model:             SARIMAX(4, 1, 2)x(1, 1, [1], 12)   Log Likelihood               -1527.609
# Date:                              Tue, 28 Apr 2020   AIC                           3073.219
# Time:                                      09:51:39   BIC                           3101.063
# Sample:                                           0   HQIC                          3084.523
#                                               - 176
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.5316      2.438     -0.218      0.827      -5.310       4.247
# ar.L2         -0.0733      0.444     -0.165      0.869      -0.944       0.797
# ar.L3         -0.0475      0.290     -0.164      0.870      -0.616       0.521
# ar.L4         -0.0076      0.173     -0.044      0.965      -0.348       0.332
# ma.L1         -0.0413      2.437     -0.017      0.986      -4.818       4.735
# ma.L2         -0.3773      1.706     -0.221      0.825      -3.722       2.967
# ar.S.L12       0.1961      0.158      1.242      0.214      -0.113       0.506
# ma.S.L12      -0.5765      0.156     -3.694      0.000      -0.882      -0.271
# sigma2      7.537e+06    7.4e+05     10.180      0.000    6.09e+06    8.99e+06
# ===================================================================================
# Ljung-Box (Q):                       48.63   Jarque-Bera (JB):                19.06
# Prob(Q):                              0.16   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.14   Skew:                            -0.56
# Prob(H) (two-sided):                  0.63   Kurtosis:                         4.24
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 9.84e+14. Standard errors may be unstable.

# %%
arima = SARIMAX(data['wine'].values, order=(2,1,1), seasonal_order=(1, 1, 1, 12)).fit()


plt.plot(arima.resid)
plot_pacf(arima.resid, lags=15)
plot_acf(arima.resid, lags=15)

plt.show()

# %%
plt.scatter(range(16), acorr_ljungbox(arima.resid, lags=16)[1])

plt.show()
# Out:
# /Users/vitalijugnivenko/opt/anaconda3/lib/python3.7/site-packages/statsmodels/stats/diagnostic.py:524: FutureWarning: The value returned will change to a single DataFrame after 0.12 is released.  Set return_df to True to use to return a DataFrame now.  Set return_df to False to silence this warning.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Q-Q plot:

# %%
_ = st.probplot(arima.resid, plot=plt)
print (st.shapiro(arima.resid))
plt.show()
plt.hist(arima.resid)

plt.show()
# Out:
# (0.8828683495521545, 1.630462986845771e-10)

# %%
arima = SARIMAX(data['wine'].values[:-12], order=(2,1,1), seasonal_order=(1,1,1,12)).fit()
predicted = arima.predict(0, data.shape[0])

# %%
plt.plot(data['wine'].values[:-12], alpha=0.5, ls='--')
plt.plot(range(len(data['wine'].values[:-12]), len(data['wine'])), data['wine'].values[-12:], alpha=0.5, ls='--')
plt.plot(predicted)

plt.show()

# %%
arima = SARIMAX(data['wine'].values[:-12], order=(2,1,1), seasonal_order=(1,1,1,12)).fit()
predicted = arima.predict(data.shape[0]-12, data.shape[0]-1, dynamic=True)

# %%
plt.plot(data['wine'].values[:-12], alpha=0.5, ls='--')
plt.plot(range(len(data['wine'].values[:-12]), len(data['wine'])), data['wine'].values[-12:], alpha=0.5, ls='--')
plt.plot(range(len(data['wine'].values[:-12]), len(data['wine'])), predicted)

plt.show()

# %% [markdown]
# # Прогноз ETS

# %%
ets = ExponentialSmoothing(data['wine'].values[12:]).fit(optimized=True)

predicted = ets.predict(0, data.shape[0])

plt.plot(data['wine'].values[:-12], alpha=0.5, ls='--')
plt.plot(range(len(data['wine'].values[:-12]), len(data['wine'])), data['wine'].values[-12:], alpha=0.5, ls='--')
plt.plot(predicted)

plt.show()

# %%
ets = ExponentialSmoothing(data['wine'].values[12:], trend='add').fit()

predicted = ets.predict(0, data.shape[0])

plt.plot(data['wine'].values[:-12], alpha=0.5, ls='--')
plt.plot(range(len(data['wine'].values[:-12]), len(data['wine'])), data['wine'].values[-12:], alpha=0.5, ls='--')
plt.plot(predicted)

plt.show()
# Out:
# /Users/vitalijugnivenko/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/holtwinters.py:744: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)

# %%
ets = ExponentialSmoothing(data['wine'].values[12:], seasonal='mul', trend='add', seasonal_periods=12).fit()

predicted = ets.predict(0, data.shape[0])

plt.plot(data['wine'].values[:-12], alpha=0.5, ls='--')
plt.plot(range(len(data['wine'].values[:-12]), len(data['wine'])), data['wine'].values[-12:], alpha=0.5, ls='--')
plt.plot(predicted)

plt.show()

# %%
_ = st.probplot(ets.resid, plot=plt)
print (st.shapiro(ets.resid))
plt.show()

plt.hist(ets.resid)
plt.show()
# Out:
# (0.9575194716453552, 6.833939551142976e-05)

# %%
ets = ExponentialSmoothing(data['wine'].values[12:], seasonal='mul', trend='add', seasonal_periods=12).fit(use_boxcox=True)

predicted = ets.predict(0, data.shape[0])

plt.plot(data['wine'].values[:-12], alpha=0.5, ls='--')
plt.plot(range(len(data['wine'].values[:-12]), len(data['wine'])), data['wine'].values[-12:], alpha=0.5, ls='--')
plt.plot(predicted)

plt.show()
# Out:
# /Users/vitalijugnivenko/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/holtwinters.py:744: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)

# %%
_ = st.probplot(ets.resid, plot=plt)
print (st.shapiro(ets.resid))
plt.show()

plt.hist(ets.resid)
plt.show()
# Out:
# (0.957351565361023, 6.589614349650219e-05)

# %%
ets = ExponentialSmoothing(data['bc'].values[12:], seasonal='mul', trend='add', seasonal_periods=12).fit()

predicted = ets.predict(0, data.shape[0])

plt.plot(data['bc'].values[:-12], alpha=0.5, ls='--')
plt.plot(range(len(data['bc'].values[:-12]), len(data['bc'])), data['bc'].values[-12:], alpha=0.5, ls='--')
plt.plot(predicted)

plt.show()

# %%
_ = st.probplot(ets.resid, plot=plt)
print (st.shapiro(ets.resid))
plt.show()

plt.hist(ets.resid)
plt.show()
# Out:
# (0.9607381224632263, 0.00013918183685746044)
